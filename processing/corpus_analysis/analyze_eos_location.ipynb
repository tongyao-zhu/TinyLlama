# %%
import numpy as np

location_dict = {}

for ds_version in ['cc_8k',  'cc_merged_v2_8k', ]:
    location_dict[ds_version] = np.load(f"/home/aiops/zhuty/tinyllama/processing/corpus_analysis/eos_locations_{ds_version}.npy")

# %%
print(len(location_dict['cc_8k']), len(location_dict['cc_merged_v2_8k']))
# Out:
# 834269 835179

# %%
# Plot the histogram of the distribution of locations of each data
import matplotlib.pyplot as plt
# plt.hist(location_dict['cc_8k'], bins=100, alpha=0.5, label='cc_8k')
plt.hist(location_dict['cc_merged_v2_8k'], bins=100, alpha=0.5, label='cc_merged_v2_8k')
# Out:
# (array([8460., 8381., 8297., 8406., 8488., 8218., 8428., 8368., 8369.,
#         8228., 8300., 8534., 8287., 8423., 8318., 8532., 8353., 8385.,
#         8214., 8230., 8397., 8262., 8318., 8311., 8140., 8267., 8297.,
#         8356., 8339., 8485., 8334., 8426., 8415., 8282., 8269., 8387.,
#         8347., 8337., 8420., 8359., 8366., 8393., 8316., 8180., 8335.,
#         8357., 8291., 8305., 8358., 8275., 8442., 8401., 8259., 8483.,
#         8396., 8555., 8411., 8433., 8420., 8430., 8259., 8162., 8220.,
#         8374., 8386., 8402., 8360., 8405., 8263., 8447., 8255., 8256.,
#         8552., 8292., 8169., 8413., 8228., 8375., 8379., 8411., 8609.,
#         8226., 8392., 8391., 8312., 8300., 8441., 8123., 8332., 8323.,
#         8463., 8368., 8325., 8264., 8394., 8346., 8375., 8508., 8470.,
#         8236.]),
#  array([   0.  ,   81.92,  163.84,  245.76,  327.68,  409.6 ,  491.52,
#          573.44,  655.36,  737.28,  819.2 ,  901.12,  983.04, 1064.96,
# ...

# %%
a = ""
if "hi" and "":
    print("asb")
